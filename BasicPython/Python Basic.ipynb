# %%
# Python Basic
# Let's get started

def end():
    print("\n"+"="*20+"\n")

# Imajiner
a = 20
b = 3*a
# print(b)

# if((2==2) == True):
#     print("LMAO")


# List
x = [5,10,15,20,25,30,35,40]
x[1:7:3]
# Del
# del x[1]
# x


#Tuple
day = ('Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday')
day[2]


# Set
# Set use for unique elemen
# Delete duplicate value at the same time
a = {1,2,2,3,3,3}
# print(a)


# Dictionary
# Data Collection which have Pair Key and Value
d = {1:'value','key':2}
# print(dict([[1,2],[3,4]]))
# print(type(d)) 
# print(d)

# a = 5.5
# print(type(a))


a, b = 10, 11
a, b
# print('a: %x and b: %X' % (a, b))


# Dynamic Typing
# IsInstance
# print(isinstance(a,int))

# DInamys type
a = True
a = 12
if False:
    a = 9 + "satu"  # Baris ini tidak dioperasikan, sehingga tidak muncul notifikasi TypeError
else:
    a = 9 + 1
# print(a)



# Numeric , Char , and String Transfomrasion

# strip
strA = "Vicktor Lambok Desrony"
print(strA.strip())
# Starwith and Endwith
print(strA.startswith("Vicktor"))
print(strA.endswith("Desrony"))

# Combine and Split string
print('Dicoding Indonesia !'.split(sep=' '))
#  isupper(), islower(), isalpha(), isalnum(), isdecimal()
# istitle() , isspace()


# Formatting
angka = -0.45
print (str(angka).zfill(7));

# Teks position
# rjust(), ljust(), and center()
strA = "Vicktor"
print(strA.rjust(20,'-'))
print(strA.ljust(20,'-'))
print(strA.center(20,'-'))


# Operation in List , Set , String
contoh_list = [1, 3, 3, 5, 5, 5, 7, 7, 9]
print(contoh_list)
print(len(contoh_list))
 
contoh_set = set([1, 3, 3, 5, 5, 5, 7, 7, 9])
print(contoh_set)
print(len(contoh_set))
 
contoh_string = "Belajar Python"
print(contoh_string)
print(len(contoh_string))
end()

# Fill value for multiple variable
arrA = ['Andy',12,'Memancing']
name , age , hobby = arrA
print("\nName : %s\nAge : %d\nHobby :%s"%(name,age,hobby))
end()

# Sort
kendaraan = ['motor', 'mobil', 'helikopter', 'pesawat']
kendaraan.sort(reverse=True)
print("\n",kendaraan)
kendaraan = ['Motor', 'Mobil', 'helikopter', 'pesawat']
kendaraan.sort(key=str.lower)
print(kendaraan)
end()

# le, lt , gt , ge , eq , ne
from operator import *
hijau = 5
kuning = 10
print('Kelereng Hijau = {}'.format(hijau))
print('Kelereng Kuning = {}'.format(kuning))
for func in (lt, le, eq, ne, ge, gt):
    print('{}(hijau, kuning): {}'.format(func.__name__, func(hijau, kuning)))
end()


# Code Format
#### using Black #####
# Docs => https://black.now.sh
# Install => pip install black

### YAPF (Yet Another Python Formatter) ###
# Docs => https://yapf.now.sh
# Install => pip install yapf


# Autopep8
# Docs => https://github.com/hhatto/autopep8
# Install => pip install autopep8


# Conditional
nice = True
## using Ternary
### Tenary
kata = "selamat" if (2==2) else "perbaiki"
print(kata)
### Tuple ternary
kata= ("perbaiki", "selamat")[2==2]
print(kata)
### ShortHand Ternary
hasil = None
pesan = hasil or "Tidak ada data"
print(pesan)
end()

## Pass (continue in C/C++)
for i in range(1,5):
    if(i%2==0):
        pass
    else:
        print(i)
end()

import sys
data=''
while(data!='exit'):
    try:
        data='exit'
        print('got integer: {}'.format(int(data)))
    except:
        if data == 'exit':
            pass  # exit gracefully without prompt any error
        else:
            print('error: {}'.format(sys.exc_info()[0]))
end()


## List Comprehension
list1 = ['d', 'i', 'c', 'o']
list2 = ['d', 'i', 'c', 'g']
duplikat = [a for a in list1 for b in list2 if a == b]
print(duplikat) # Output: ['d','i']
end()

print([[i+2,i+4] for i in range(1,5) if i%2==1])

# 1 , 3 ,5 ,7 , 9
list_a = range(1, 10, 2)
x = [[a**2, a**3] for a in list_a]
myAns = [[1,1],[9,27],[25,125],[49,343],[81,729]]
if(x==myAns):
    print("Hoyahhh")
else:
    print(x)
end()

# Error handling and exceptions
# https://docs.python.org/id/3.8/library/exceptions.html

# Pass by reference vs value
# By Value
def ubah(list_saya):
    "Deklarasi Variabel list_saya berikut hanya dikenali (berlaku) di dalam fungsi ubah"
    list_saya = [1, 2, 3, 4] 
    print ('Nilai di dalam fungsi: {}'.format(list_saya))
 
# Panggil fungsi ubah
list_saya = [10, 20, 30]
ubah(list_saya)
print('Nilai di luar fungsi: {}'.format(list_saya))

# By Reference
def printinfo(*args, **kwargs):
    for a in args:
        print('argumen posisi {}'.format(a))
    for key, value in kwargs.items():
        print('argumen kata kunci {}:{}'.format(key, value))
 
 
# Panggil printinfo
# printinfo()
# printinfo(1, 2, 3, 5, 6, 7)
# printinfo(i=7, j=8, k=9)
# printinfo(1, 2, j=8, k=9)
printinfo(*(2, 3), **{'i':7, 'j':8})
end()

def cetak_info(name = 'Dicoding', age=5):
   print('Nama:', name , 'dan' ' Umur:',age)
 
cetak_info(name, age)

def cetak(param):
    print(param)
    return
 
cetak("Dicoding Indonesia")

def penjumlahan(a, b):
    a+b
 
hasil = penjumlahan(10, 10)
print(hasil)
# Out:
# Vicktor Lambok Desrony
# True
# True
# ['Dicoding', 'Indonesia', '!']
# -000.45
# -------------Vicktor
# Vicktor-------------
# ------Vicktor-------
# [1, 3, 3, 5, 5, 5, 7, 7, 9]
# 9
# {1, 3, 5, 7, 9}
# 5
# Belajar Python
# 14
#
# ...
#
#
# Name : Andy
# Age : 12
# Hobby :Memancing
#
# ...
#
#
#  ['pesawat', 'motor', 'mobil', 'helikopter']
# ['helikopter', 'Mobil', 'Motor', 'pesawat']
#
# ...
#
# Kelereng Hijau = 5
# Kelereng Kuning = 10
# lt(hijau, kuning): True
# le(hijau, kuning): True
# eq(hijau, kuning): False
# ne(hijau, kuning): True
# ge(hijau, kuning): False
# gt(hijau, kuning): False
#
# ...
#
# selamat
# selamat
# Tidak ada data
#
# ...
#
# 1
# 3
#
# ...
#
#
# ...
#
# ['d', 'i', 'c']
#
# ...
#
# [[3, 5], [5, 7]]
# Hoyahhh
#
# ...
#
# Nilai di dalam fungsi: [1, 2, 3, 4]
# Nilai di luar fungsi: [10, 20, 30]
# argumen posisi 2
# argumen posisi 3
# argumen kata kunci i:7
# argumen kata kunci j:8
# Nama: Andy dan Umur: 12
# Dicoding Indonesia
# None

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f5fe3404-7e72-4b0a-b35c-428fae106643' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
